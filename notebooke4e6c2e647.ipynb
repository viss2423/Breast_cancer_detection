# %%
pip uninstall -y enum34 && pip install --upgrade pip setuptools wheel && apt-get update && apt-get install ffmpeg libsm6 libxext6  -y

# %%
# !python --version

# %%
# !pip install wandb --upgrade

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# !pip install -r yolov5/requirements.txt

# %%
cd yolov5/

# %%
# !pip install wandb

# %%
# !wandb login d9b30dfd0027890539acd7f5cf8e8f19ff91f9b2

# %%
# !python train.py --img 640 --epochs 50 --data /kaggle/input/vindr-40k-yaml/set_1.yaml --weights /kaggle/input/yolov5m/yolov5m.pt --name yolo_vindr_40k_m_50 --project yolo_vindr_40k --device 0 --workers 4
